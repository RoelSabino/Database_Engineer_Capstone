# %% [markdown]
# # Meta Database Engineer Capstone

# %% [markdown]
# ## 1st Exercise
# ### Task 1

# %%
# !python --version
# Out:
# Python 3.14.2

# %% [markdown]
# ### Task 2

# %% [markdown]
# ##### Following commands ran to configure and create this jupyter notebook
# - python -m pip install jupyter
# - jupyter notebook

# %% [markdown]
# ### Task 3
# #### Step 1

# %%
# !pip install mysql-connector-python
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# #### Step 2

# %%
import mysql.connector as connector

# %% [markdown]
# #### Step 3

# %%
connection = connector.connect(user = "roel", password = "")

# %%
connection.is_connected()
# Out:
# True

# %% [markdown]
# ## 2nd Exercise
# ### Task 1

# %%
connection = connector.connect(user = "roel", password = "", db = "little_lemon")

# %% [markdown]
# ### Task 2

# %%
with connection.cursor() as cursor:
    show_tables_query = "SHOW tables" 
    cursor.execute(show_tables_query)
    results = cursor.fetchall()
    print(results)
# Out:
# [('addresses',), ('bookings',), ('cities',), ('countries',), ('courses',), ('cuisines',), ('customers',), ('deliveries',), ('desserts',), ('menus',), ('orders',), ('ordersview',), ('postalcodes',), ('sides',), ('starters',)]

# %% [markdown]
# ### Task 3

# %%
query_stmt = """
    SELECT customers.FullName, customers.ContactNumber, orders.TotalCost
    FROM customers
    LEFT JOIN orders ON orders.CustomerID = customers.CustomerID
    WHERE orders.TotalCost > 60;
"""
with connection.cursor() as cursor:
    cursor.execute(query_stmt)
    results = cursor.fetchall()
    print(results)
# Out:
# [('Customer A', 'A12345678', Decimal('600.00')), ('Customer A', 'A12345678', Decimal('100.00'))]
